# %% [markdown]
# # Steps to Follow for making an accurate ML Model and data solving

# %% [markdown]
# 1---> Visualize the data for 30 mins.
#
# 2---> Read Data
#
# 3---> Check for Duplicate rows and Delete them.
#
#      code to use-->flight_rate=flight_rate.drop_duplicates()#Removes only those rows that are completely duplicated.
#
# 4---> Check the types of column and convert using .astype
#
# 5---> Check for NULL values and either delete or fill those values in columns.
#
#             FILL COLUMN METHOD----> #Contious values--> Use Median
#
#                                     #Categorical values--> Use Mode
#
# 6--->PLot the categorical and continous graphs and observe them seperately.
#
# 7---> Feature engineering(Column Transformations)
#
# 8---> Feature Scaling(normalization, stardization)

# %%
import pandas as pd
import numpy as np

# %%
flight_rate=pd.read_excel("Flight Dataset/Data_Train.xlsx")
flight_rate.shape
flight_rate.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# a=pd.read_excel("Data_Train.xlsx")
# a[a["Route"]=="BOM → GOI → PNQ → HYD"] Method to find some particular value in dataset using correct indexing

# %%
flight_rate.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      24/03/2019  Banglore   New Delhi
# 1          Air India       1/05/2019   Kolkata    Banglore
# 2        Jet Airways       9/06/2019     Delhi      Cochin
# 3             IndiGo      12/05/2019   Kolkata    Banglore
# 4             IndiGo      01/03/2019  Banglore   New Delhi
# 5           SpiceJet      24/06/2019   Kolkata    Banglore
# 6        Jet Airways      12/03/2019  Banglore   New Delhi
# 7        Jet Airways      01/03/2019  Banglore   New Delhi
# 8        Jet Airways      12/03/2019  Banglore   New Delhi
# 9  Multiple carriers      27/05/2019     Delhi      Cochin
#
#                    Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# ...

# %%
flight_rate.info()
flight_rate.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB
# (10683, 11)

# %%
flight_rate=flight_rate.drop_duplicates()#Removes only those rows that are completely duplicated

# %%
flight_rate.shape
# Out:
# (10463, 11)

# %%
flight_rate.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
flight_rate['Date_of_Journey']=flight_rate['Date_of_Journey'].astype("datetime64[ns]")

# %%
flight_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10463 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Date_of_Journey  10463 non-null  datetime64[ns]
#  2   Source           10463 non-null  object
#  3   Destination      10463 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10463 non-null  object
#  6   Arrival_Time     10463 non-null  object
#  7   Duration         10463 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10463 non-null  object
#  10  Price            10463 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 980.9+ KB

# %%
flight_rate['Dep_Time']=flight_rate['Dep_Time'].astype("datetime64[ns]")
flight_rate['Arrival_Time']=flight_rate['Arrival_Time'].astype("datetime64[ns]")
flight_rate['Price']=flight_rate['Price'].astype("float")

# %%
# flight_rate['Duration']=flight_rate['Duration'].apply(lamda: x)
A=list(flight_rate.Duration)
A
# Out:
# ['2h 50m',
#  '7h 25m',
#  '19h',
#  '5h 25m',
#  '4h 45m',
#  '2h 25m',
#  '15h 30m',
#  '21h 5m',
#  '25h 30m',
#  '7h 50m',
#  '13h 15m',
#  '2h 35m',
#  '2h 15m',
#  '12h 10m',
#  '2h 35m',
#  '26h 35m',
#  '4h 30m',
#  '22h 35m',
#  '23h',
#  '20h 35m',
#  '5h 10m',
#  '15h 20m',
#  '2h 50m',
#  '2h 55m',
#  '13h 20m',
#  '15h 10m',
#  '5h 45m',
#  '5h 55m',
#  '2h 50m',
#  '2h 15m',
#  '2h 15m',
#  '13h 25m',
#  '2h 50m',
#  '22h',
#  '5h 30m',
#  '10h 25m',
#  '5h 15m',
#  '2h 30m',
#  '6h 15m',
#  '11h 55m',
#  '11h 5m',
#  '8h 30m',
#  '22h 5m',
#  '2h 45m',
#  '12h',
#  '2h 50m',
#  '2h 50m',
#  '2h 15m',
#  '16h 5m',
#  '19h 55m',
#  '3h 15m',
#  '25h 20m',
#  '2h 50m',
#  '3h',
#  '2h 50m',
#  '16h 15m',
#  '15h 5m',
#  '2h 15m',
#  '6h 30m',
#  '25h 5m',
#  '12h 25m',
#  '27h 20m',
#  '10h 15m',
#  '10h 30m',
#  '2h 15m',
#  '10h 25m',
#  '2h 50m',
#  '1h 30m',
#  '13h 20m',
#  '2h 15m',
#  '1h 25m',
#  '26h 30m',
#  '7h 20m',
#  '13h 30m',
#  '5h',
#  '2h 45m',
# ...

# %%
'''a[0]=list(a[0])
a[0][1]=":"
a[0]
a[0] = ''.join(a[0])
a[0]'''
# Out:
# 'a[0]=list(a[0])\na[0][1]=":"\na[0]\na[0] = \'\'.join(a[0])\na[0]'

# %%
def swaplist(x):
    list1=[]
    for j in x.split(): #2h , 30m
        if "h" in j: #2h
            a=j.strip("h") #2
            a=int(a)*60  #120
            list1.append(a)
        elif "m" in j:
            b=j.strip("m")
            b=int(b)
            list1.append(b)    
        else:
              pass
    return sum(list1)

# %%
a="2h"
j=a.strip("h")
j
# Out:
# '2'

# %%
swaplist("2h 30m")
# Out:
# 150

# %%
flight_rate['Duration'] = flight_rate['Duration'].apply(lambda x:swaplist(x)) #Using lambda function to replace ',' from cost
#flight_rate['Duration'] = datetime.strptime(flight_rate['Duration'], '%H::%M::%S').time()
#flight_rate['Duration'] = ' '.join(flight_rate['Duration'])

# %%
flight_rate.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time  Duration Total_Stops  \
# 0 2022-04-16 22:20:00 2022-03-22 01:10:00       170    non-stop
# 1 2022-04-16 05:50:00 2022-04-16 13:15:00       445     2 stops
# 2 2022-04-16 09:25:00 2022-06-10 04:25:00      1140     2 stops
# 3 2022-04-16 18:05:00 2022-04-16 23:30:00       325      1 stop
# 4 2022-04-16 16:50:00 2022-04-16 21:35:00       285      1 stop
#
#   Additional_Info    Price
# 0         No info   3897.0
# 1         No info   7662.0
# 2         No info  13882.0
# ...

# %%
flight_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10463 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Date_of_Journey  10463 non-null  datetime64[ns]
#  2   Source           10463 non-null  object
#  3   Destination      10463 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10463 non-null  datetime64[ns]
#  6   Arrival_Time     10463 non-null  datetime64[ns]
#  7   Duration         10463 non-null  int64
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10463 non-null  object
#  10  Price            10463 non-null  float64
# dtypes: datetime64[ns](3), float64(1), int64(1), object(6)
# memory usage: 980.9+ KB

# %%
flight_rate["Duration in minute"]=flight_rate["Duration"]

# %%
flight_rate.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time  Duration Total_Stops  \
# 0 2022-04-16 22:20:00 2022-03-22 01:10:00       170    non-stop
# 1 2022-04-16 05:50:00 2022-04-16 13:15:00       445     2 stops
# 2 2022-04-16 09:25:00 2022-06-10 04:25:00      1140     2 stops
# 3 2022-04-16 18:05:00 2022-04-16 23:30:00       325      1 stop
# 4 2022-04-16 16:50:00 2022-04-16 21:35:00       285      1 stop
#
#   Additional_Info    Price  Duration in minute
# 0         No info   3897.0                 170
# ...

# %%
flight_rate.drop("Duration", axis=1,inplace=True)

# %%
flight_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10463 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Airline             10463 non-null  object
#  1   Date_of_Journey     10463 non-null  datetime64[ns]
#  2   Source              10463 non-null  object
#  3   Destination         10463 non-null  object
#  4   Route               10462 non-null  object
#  5   Dep_Time            10463 non-null  datetime64[ns]
#  6   Arrival_Time        10463 non-null  datetime64[ns]
#  7   Total_Stops         10462 non-null  object
#  8   Additional_Info     10463 non-null  object
#  9   Price               10463 non-null  float64
#  10  Duration in minute  10463 non-null  int64
# dtypes: datetime64[ns](3), float64(1), int64(1), object(6)
# memory usage: 980.9+ KB

# %%
flight_rate.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Total_Stops           1
# Additional_Info       0
# Price                 0
# Duration in minute    0
# dtype: int64

# %%
flight_rate[flight_rate["Route"]==np.NaN].count()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Total_Stops           0
# Additional_Info       0
# Price                 0
# Duration in minute    0
# dtype: int64

# %%
flight_rate[flight_rate.Route.isna()]
# Out:
#         Airline Date_of_Journey Source Destination Route            Dep_Time  \
# 9039  Air India      2019-06-05  Delhi      Cochin   NaN 2022-04-16 09:45:00
#
#             Arrival_Time Total_Stops Additional_Info   Price  \
# 9039 2022-05-07 09:25:00         NaN         No info  7480.0
#
#       Duration in minute
# 9039                1420

# %%
# Code to delete all the missing values at once
print('Before Deleting missing values:', flight_rate.shape)
flight_rate.dropna(inplace=True)
print('After Deleting missing values:', flight_rate.shape)
# Out:
# Before Deleting missing values: (10463, 11)
# After Deleting missing values: (10462, 11)

# %%
flight_rate.groupby("Source")["Source"].count()
# Out:
# Source
# Banglore    2179
# Chennai      381
# Delhi       4345
# Kolkata     2860
# Mumbai       697
# Name: Source, dtype: int64

# %%
flight_rate.groupby("Destination")["Destination"].count()
# Out:
# Destination
# Banglore     2860
# Cochin       4345
# Delhi        1265
# Hyderabad     697
# Kolkata       381
# New Delhi     914
# Name: Destination, dtype: int64

# %%
flight_rate.Destination.replace("New Delhi","Delhi", inplace=True)

# %%
flight_rate.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore       Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore       Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Total_Stops Additional_Info  \
# 0 2022-04-16 22:20:00 2022-03-22 01:10:00    non-stop         No info
# 1 2022-04-16 05:50:00 2022-04-16 13:15:00     2 stops         No info
# 2 2022-04-16 09:25:00 2022-06-10 04:25:00     2 stops         No info
# 3 2022-04-16 18:05:00 2022-04-16 23:30:00      1 stop         No info
# 4 2022-04-16 16:50:00 2022-04-16 21:35:00      1 stop         No info
#
#      Price  Duration in minute
# 0   3897.0                 170
# ...

# %%
flight_rate.describe(include="all")
# Out:
# <ipython-input-32-4184a2f28841>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   flight_rate.describe(include="all")
# <ipython-input-32-4184a2f28841>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   flight_rate.describe(include="all")
# <ipython-input-32-4184a2f28841>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   flight_rate.describe(include="all")
# ...

# %%
# %matplotlib inline
flight_rate.hist(['Price'], figsize=[10,3])
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
import numpy as np
flight_rate[flight_rate.Price>25000].count()
# Out:
# Airline               82
# Date_of_Journey       82
# Source                82
# Destination           82
# Route                 82
# Dep_Time              82
# Arrival_Time          82
# Total_Stops           82
# Additional_Info       82
# Price                 82
# Duration in minute    82
# dtype: int64

# %%
flight_rate.nunique()
# Out:
# Airline                 12
# Date_of_Journey         40
# Source                   5
# Destination              5
# Route                  128
# Dep_Time               222
# Arrival_Time          1343
# Total_Stops              5
# Additional_Info         10
# Price                 1870
# Duration in minute     368
# dtype: int64

# %%
flight_rate['Price'][flight_rate['Price']>25000]=25000
# flight_rate["Price"]["Price"]>25000=25000
flight_rate[flight_rate.Price>25000].count()
# Out:
# <ipython-input-36-1a30d78cea54>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight_rate['Price'][flight_rate['Price']>25000]=25000
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Total_Stops           0
# Additional_Info       0
# Price                 0
# Duration in minute    0
# dtype: int64

# %%
flight_rate.hist(['Price'], figsize=[10,3])
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
flight_rate["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
flight_rate["Additional_Info"].replace(to_replace="No Info", value="No info", inplace=True)

# %%
def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(18,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# Calling the function
PlotBarCharts(inpData=flight_rate, colsToPlot=['Source', 'Destination','Total_Stops','Additional_Info','Airline'])

# %%
# f_oneway() function takes the group data as input and returns F-statistic and P-value
from scipy.stats import f_oneway


# Running the one-way anova test between Price and Additional_info
# Assumption(H0) is that Additional_info and Prices are NOT correlated

# Finds out the Prices data for each  as a list
CategoryGroupLists=flight_rate.groupby('Additional_Info')['Price'].apply(list)
# Performing the ANOVA test
AnovaResults = f_oneway(*CategoryGroupLists)


# Extreme example when all values are same and the variables are not correlated
#AnovaResults = f_oneway( [10,20], [10,20], [10,20] )

# Extreme example when all the values are different and both variables has correlation
#AnovaResults = f_oneway( [400,500], [7,10], [0.006,0.00001] )

print('P-Value for Anova is: ', AnovaResults[1])
AnovaResults

# We accept the Assumption(H0) only when P-Value > 0.05
# Here the P-Value is > 0.05 by a slight margin!! which means we will Accept the Assumption(H0)
# This means Price and Fuel Type are NOT correlated
# Out:
# P-Value for Anova is:  1.2976266405006287e-159
# F_onewayResult(statistic=99.02098559690731, pvalue=1.2976266405006287e-159)

# %%
flight_rate.drop(labels = ["Additional_Info"], axis = "columns", inplace = True)

# %%
# f_oneway() function takes the group data as input and returns F-statistic and P-value
from scipy.stats import f_oneway


# Running the one-way anova test between Price and Source
# Assumption(H0) is that FuelType and Prices are NOT correlated

# Finds out the Prices data for each  as a list
CategoryGroupLists=flight_rate.groupby('Source')['Price'].apply(list)
# Performing the ANOVA test
AnovaResults = f_oneway(*CategoryGroupLists)


# Extreme example when all values are same and the variables are not correlated
#AnovaResults = f_oneway( [10,20], [10,20], [10,20] )

# Extreme example when all the values are different and both variables has correlation
#AnovaResults = f_oneway( [400,500], [7,10], [0.006,0.00001] )

print('P-Value for Anova is: ', AnovaResults[1])
AnovaResults

# We accept the Assumption(H0) only when P-Value > 0.05
# Here the P-Value is > 0.05 by a slight margin!! which means we will Accept the Assumption(H0)
# This means Price and Fuel Type are NOT correlated
# Out:
# P-Value for Anova is:  0.0
# F_onewayResult(statistic=465.9400302954277, pvalue=0.0)

# %%
# f_oneway() function takes the group data as input and returns F-statistic and P-value
from scipy.stats import f_oneway


# Running the one-way anova test between Price and FuelTypes
# Assumption(H0) is that FuelType and Prices are NOT correlated

# Finds out the Prices data for each  as a list
CategoryGroupLists=flight_rate.groupby('Destination')['Price'].apply(list)
# Performing the ANOVA test
AnovaResults = f_oneway(*CategoryGroupLists)


# Extreme example when all values are same and the variables are not correlated
#AnovaResults = f_oneway( [10,20], [10,20], [10,20] )

# Extreme example when all the values are different and both variables has correlation
#AnovaResults = f_oneway( [400,500], [7,10], [0.006,0.00001] )

print('P-Value for Anova is: ', AnovaResults[1])
AnovaResults

# We accept the Assumption(H0) only when P-Value > 0.05
# Here the P-Value is > 0.05 by a slight margin!! which means we will Accept the Assumption(H0)
# This means Price and Fuel Type are NOT correlated
# Out:
# P-Value for Anova is:  0.0
# F_onewayResult(statistic=465.9400302954277, pvalue=0.0)

# %%
# f_oneway() function takes the group data as input and returns F-statistic and P-value
from scipy.stats import f_oneway


# Running the one-way anova test between Price and Total_Stops
# Assumption(H0) is that Total_Stops and Prices are NOT correlated

# Finds out the Prices data for each  as a list
CategoryGroupLists=flight_rate.groupby('Total_Stops')['Price'].apply(list)
# Performing the ANOVA test
AnovaResults = f_oneway(*CategoryGroupLists)


# Extreme example when all values are same and the variables are not correlated
#AnovaResults = f_oneway( [10,20], [10,20], [10,20] )

# Extreme example when all the values are different and both variables has correlation
#AnovaResults = f_oneway( [400,500], [7,10], [0.006,0.00001] )

print('P-Value for Anova is: ', AnovaResults[1])
AnovaResults

# We accept the Assumption(H0) only when P-Value > 0.05
# Here the P-Value is > 0.05 by a slight margin!! which means we will Accept the Assumption(H0)
# This means Price and Fuel Type are NOT correlated
# Out:
# P-Value for Anova is:  0.0
# F_onewayResult(statistic=2094.6145854342417, pvalue=0.0)

# %%
flight_rate.hist(['Price','Duration in minute', 'Arrival_Time', 'Dep_Time','Route'], figsize=(18,8))
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'Duration in minute'}>],
#        [<AxesSubplot:title={'center':'Arrival_Time'}>,
#         <AxesSubplot:title={'center':'Dep_Time'}>]], dtype=object)

# %%
flight_rate.Date_of_Journey.values
# Out:
# array(['2019-03-24T00:00:00.000000000', '2019-01-05T00:00:00.000000000',
#        '2019-09-06T00:00:00.000000000', ...,
#        '2019-04-27T00:00:00.000000000', '2019-01-03T00:00:00.000000000',
#        '2019-09-05T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
flight_rate.hist('Date_of_Journey', figsize=(18,8))
# Out:
# array([[<AxesSubplot:title={'center':'Date_of_Journey'}>]], dtype=object)

# %%
# flight_rate.plot.scatter(x='Duration in minute', y='Price', figsize=(5,4), marker='o', color='blue')

# %%
flight_rate.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore       Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore       Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Total_Stops    Price  \
# 0 2022-04-16 22:20:00 2022-03-22 01:10:00    non-stop   3897.0
# 1 2022-04-16 05:50:00 2022-04-16 13:15:00     2 stops   7662.0
# 2 2022-04-16 09:25:00 2022-06-10 04:25:00     2 stops  13882.0
# 3 2022-04-16 18:05:00 2022-04-16 23:30:00      1 stop   6218.0
# 4 2022-04-16 16:50:00 2022-04-16 21:35:00      1 stop  13302.0
#
#    Duration in minute
# 0                 170
# 1                 445
# 2                1140
# 3                 325
# ...

# %%
import matplotlib.pyplot as plt

# Generating multiple subplots
fig, subPlot=plt.subplots(nrows=1, ncols=4, figsize=(30,12))

# Creating the super title of the charts
fig.suptitle('Price Vs Duration in minute, Arrival_Time, Dep_Time and Route')

# Generating multiple scatter charts
flight_rate.plot.scatter(x='Duration in minute', y='Price', marker='o', color='blue', ax=subPlot[0])
flight_rate.plot.scatter(x='Arrival_Time', y='Price', marker='o', color='blue', ax=subPlot[1])
flight_rate.plot.scatter(x='Route', y='Price', marker='o', color='blue', ax=subPlot[2])
flight_rate.plot.scatter(x='Dep_Time', y='Price', marker='o', color='blue', ax=subPlot[3])
# Out:
# <AxesSubplot:xlabel='Dep_Time', ylabel='Price'>

# %%
# a=flight_rate.Dep_Time.iloc[0]
# a
# a.month
# flight_rate.Dep_Time
# flight_rate.Dep_Time.dtype
# flight_rate["Dep_Time"]=flight_rate["Dep_Time"].astype(object)
# flight_rate.Dep_Time.dtype
# flight_rate.Dep_Time=flight_rate.Dep_Time.astype("datetime64[ns]")
# def month(x):
#     list1=[]
#     for j in x: 
#         a=j.month
#         list1.append(a)
#     return list1

# %%
def month(x):
    return x.month

# %%
flight_rate['Dep_Time'] = flight_rate['Dep_Time'].apply(lambda x:month(x)) 
flight_rate['Arrival_Time'] = flight_rate['Arrival_Time'].apply(lambda x:month(x)) 
flight_rate = flight_rate.rename(columns={'Arrival_Time':'Arrival_month','Dep_Time':'Dep_month'})
flight_rate.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      2019-03-24  Banglore       Delhi
# 1          Air India      2019-01-05   Kolkata    Banglore
# 2        Jet Airways      2019-09-06     Delhi      Cochin
# 3             IndiGo      2019-12-05   Kolkata    Banglore
# 4             IndiGo      2019-01-03  Banglore       Delhi
# 5           SpiceJet      2019-06-24   Kolkata    Banglore
# 6        Jet Airways      2019-12-03  Banglore       Delhi
# 7        Jet Airways      2019-01-03  Banglore       Delhi
# 8        Jet Airways      2019-12-03  Banglore       Delhi
# 9  Multiple carriers      2019-05-27     Delhi      Cochin
#
#                    Route  Dep_month  Arrival_month Total_Stops    Price  \
# 0              BLR → DEL          4              3    non-stop   3897.0
# 1  CCU → IXR → BBI → BLR          4              4     2 stops   7662.0
# 2  DEL → LKO → BOM → COK          4              6     2 stops  13882.0
# ...

# %%
flight_rate.groupby("Arrival_month")["Arrival_month"].size()
# Out:
# Arrival_month
# 3    1073
# 4    6577
# 5    1484
# 6    1328
# Name: Arrival_month, dtype: int64

# %%
flight_rate.groupby("Total_Stops")["Total_Stops"].count()
flight_rate['Total_Stops'].replace({'non-stop':0, '1 stop':1, '2 stops':2, '3 stops':3, '4 stops':4}, inplace=True)
flight_rate.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore       Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore       Delhi        BLR → NAG → DEL
#
#    Dep_month  Arrival_month  Total_Stops    Price  Duration in minute
# 0          4              3            0   3897.0                 170
# 1          4              4            2   7662.0                 445
# 2          4              6            2  13882.0                1140
# 3          4              4            1   6218.0                 325
# 4          4              4            1  13302.0                 285

# %%
flight_rate.drop(["Route"], axis=1,inplace=True)
flight_rate.drop(["Airline"], axis=1,inplace=True)

# %%
flight_rate.Source.unique()
flight_rate.Source.replace({"Banglore":0, "Delhi":1, "Kolkata":2, "Chennai":3, "Mumbai":4}, inplace=True)
flight_rate.Destination.replace({"Banglore":0, "Cochin":1, "Delhi":2, "Hyderabad":3,"Kolkata":4}, inplace=True)
flight_rate.head()
# Out:
#   Date_of_Journey  Source  Destination  Dep_month  Arrival_month  Total_Stops  \
# 0      2019-03-24       0            2          4              3            0
# 1      2019-01-05       2            0          4              4            2
# 2      2019-09-06       1            1          4              6            2
# 3      2019-12-05       2            0          4              4            1
# 4      2019-01-03       0            2          4              4            1
#
#      Price  Duration in minute
# 0   3897.0                 170
# 1   7662.0                 445
# 2  13882.0                1140
# 3   6218.0                 325
# 4  13302.0                 285

# %%
FullDataPlot=pd.plotting.scatter_matrix(flight_rate,alpha=1, figsize=(30,20))
# Out:
# C:\Users\Piyush.Dhasmana\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:89: UserWarning: Attempting to set identical left == right == 4.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\Piyush.Dhasmana\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:90: UserWarning: Attempting to set identical bottom == top == 4.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\Piyush.Dhasmana\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 4.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
flight_rate.Dep_month.unique()
# Out:
# array([4], dtype=int64)

# %%
flight_rate.drop(labels = ["Dep_month"], axis = "columns", inplace = True)
flight_rate.head()
# Out:
#   Date_of_Journey  Source  Destination  Arrival_month  Total_Stops    Price  \
# 0      2019-03-24       0            2              3            0   3897.0
# 1      2019-01-05       2            0              4            2   7662.0
# 2      2019-09-06       1            1              6            2  13882.0
# 3      2019-12-05       2            0              4            1   6218.0
# 4      2019-01-03       0            2              4            1  13302.0
#
#    Duration in minute
# 0                 170
# 1                 445
# 2                1140
# 3                 325
# 4                 285

# %%
flight_rate['Date_of_Journey'] = flight_rate['Date_of_Journey'].apply(lambda x:month(x)) 
flight_rate = flight_rate.rename(columns={'Date_of_Journey':'Dep_month'})
flight_rate.head()
# Out:
#    Dep_month  Source  Destination  Arrival_month  Total_Stops    Price  \
# 0          3       0            2              3            0   3897.0
# 1          1       2            0              4            2   7662.0
# 2          9       1            1              6            2  13882.0
# 3         12       2            0              4            1   6218.0
# 4          1       0            2              4            1  13302.0
#
#    Duration in minute
# 0                 170
# 1                 445
# 2                1140
# 3                 325
# 4                 285

# %%
flight_rate.groupby("Dep_month")["Dep_month"].size()
# Out:
# Dep_month
# 1     1058
# 3     2169
# 4      424
# 5     2025
# 6     2465
# 9     1375
# 12     946
# Name: Dep_month, dtype: int64

# %%
flight_rate.drop(labels = ["Arrival_month"], axis = "columns", inplace = True)
flight_rate.head()
# Out:
#    Dep_month  Source  Destination  Total_Stops    Price  Duration in minute
# 0          3       0            2            0   3897.0                 170
# 1          1       2            0            2   7662.0                 445
# 2          9       1            1            2  13882.0                1140
# 3         12       2            0            1   6218.0                 325
# 4          1       0            2            1  13302.0                 285

# %%
flight_rate=flight_rate.sample(frac=1)

# %%
# Creating the correlation matrix
CorrelationData=flight_rate.corr()
CorrelationData
# flight_rate.Dep_month.isnull().sum()
# Out:
#                     Dep_month    Source  Destination  Total_Stops     Price  \
# Dep_month            1.000000  0.034962    -0.069236     0.065438  0.023135
# Source               0.034962  1.000000     0.071112    -0.108286 -0.176429
# Destination         -0.069236  0.071112     1.000000    -0.422656 -0.285728
# Total_Stops          0.065438 -0.108286    -0.422656     1.000000  0.638098
# Price                0.023135 -0.176429    -0.285728     0.638098  1.000000
# Duration in minute   0.056328 -0.073482    -0.383773     0.727982  0.539258
#
#                     Duration in minute
# Dep_month                     0.056328
# Source                       -0.073482
# Destination                  -0.383773
# Total_Stops                   0.727982
# Price                         0.539258
# Duration in minute            1.000000

# %%
CorrelationData['Price'][abs(CorrelationData['Price']) > 0.5 ]
# Out:
# Total_Stops           0.638098
# Price                 1.000000
# Duration in minute    0.539258
# Name: Price, dtype: float64

# %%
flight_rate.drop(labels = ["Dep_month"], axis = "columns", inplace = True)
flight_rate.head()
# Out:
#       Source  Destination  Total_Stops    Price  Duration in minute
# 4368       0            2            0   5613.0                 155
# 6384       0            2            0   4823.0                 185
# 426        0            2            0  11793.0                 155
# 3326       2            0            1   7662.0                1515
# 280        2            0            1   8529.0                1495

# %%
flight_rate.columns
# Out:
# Index(['Source', 'Destination', 'Total_Stops', 'Price', 'Duration in minute'], dtype='object')

# %%
TargetVariable='Price'
Predictors=['Source', 'Destination', 'Total_Stops','Duration in minute']
X=flight_rate[Predictors].values
y=flight_rate[TargetVariable].values

# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Multiple Linear Regression
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

# Printing all the parameters of Linear regression
print(RegModel)

# Creating the model on Training Data
LREG=RegModel.fit(X_train,y_train)
prediction=LREG.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy on Test Data:',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# LinearRegression()
# R2 Value: 0.4306780695585657
# Accuracy on Test Data: 68.98365902652321
#    Source  Destination  Total_Stops  Duration in minute    Price  \
# 0       1            1            1                 865  10262.0
# 1       0            2            0                 165  19508.0
# 2       1            1            1                1485  10262.0
# 3       1            1            1                 560   6674.0
# 4       1            1            2                1375  15129.0
#
#    PredictedPrice
# 0         10110.0
# 1          6254.0
# 2         10934.0
# 3          9705.0
# 4         14132.0

# %%
# Decision Trees (Multiple if-else statements!)
from sklearn.tree import DecisionTreeRegressor
RegModel = DecisionTreeRegressor(max_depth=3,criterion='mse')

# Printing all the parameters of Random Forest
print(RegModel)

# Creating the model on Training Data
DT=RegModel.fit(X_train,y_train)
prediction=DT.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, DT.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(DT.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# DecisionTreeRegressor(max_depth=3)
# R2 Value: 0.5078371067278888
# Accuracy 72.42052155571227
#    Source  Destination  Total_Stops  Duration in minute    Price  \
# 0       1            1            1                 865  10262.0
# 1       0            2            0                 165  19508.0
# 2       1            1            1                1485  10262.0
# 3       1            1            1                 560   6674.0
# 4       1            1            2                1375  15129.0
#
#    PredictedPrice
# 0         10548.0
# 1          5427.0
# 2         10548.0
# 3         10548.0
# 4         12587.0

# %%
# Random Forest (Bagging of multiple Decision Trees)
from sklearn.ensemble import RandomForestRegressor
RegModel = RandomForestRegressor(max_depth=2, n_estimators=100,criterion='mse')

# Good range for max_depth: 2-10 and n_estimators: 100-1000

# Printing all the parameters of Random Forest
print(RegModel)

# Creating the model on Training Data
RF=RegModel.fit(X_train,y_train)
prediction=RF.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, RF.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(RF.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# RandomForestRegressor(max_depth=2)
# R2 Value: 0.49321263374936064
# Accuracy 71.66718620698967
#    Source  Destination  Total_Stops  Duration in minute    Price  \
# 0       1            1            1                 865  10262.0
# 1       0            2            0                 165  19508.0
# 2       1            1            1                1485  10262.0
# 3       1            1            1                 560   6674.0
# 4       1            1            2                1375  15129.0
#
#    PredictedPrice
# 0         10888.0
# 1          4941.0
# 2         10888.0
# 3         10888.0
# 4         11947.0

# %%
# Adaboost (Boosting of multiple Decision Trees)
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Choosing Decision Tree with 1 level as the weak learner
DTR=DecisionTreeRegressor(max_depth=1)
RegModel = AdaBoostRegressor(n_estimators=500, base_estimator=DTR ,learning_rate=0.7)

# Printing all the parameters of Adaboost
print(RegModel)

# Creating the model on Training Data
AB=RegModel.fit(X_train,y_train)
prediction=AB.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, AB.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(AB.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=1),
#                   learning_rate=0.7, n_estimators=500)
# R2 Value: 0.4282475215457352
# Accuracy 65.92729258177845
#    Source  Destination  Total_Stops  Duration in minute    Price  \
# 0       1            1            1                 865  10262.0
# 1       0            2            0                 165  19508.0
# 2       1            1            1                1485  10262.0
# 3       1            1            1                 560   6674.0
# 4       1            1            2                1375  15129.0
#
#    PredictedPrice
# 0         11389.0
# 1          5631.0
# 2         11389.0
# 3         11389.0
# 4         11389.0

# %%
# !pip install xgboost

# %%
# Xtreme Gradient Boosting (XGBoost)
from xgboost import XGBRegressor
RegModel=XGBRegressor(max_depth=6, learning_rate=1, n_estimators=100, objective='reg:linear', booster='gbtree')

# Printing all the parameters of XGBoost
print(RegModel)

# Creating the model on Training Data
XGB=RegModel.fit(X_train,y_train)
prediction=XGB.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, XGB.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importances = pd.Series(XGB.feature_importances_, index=Predictors)
feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-76-acb0e47dcdc2> in <module>
#       1 # Xtreme Gradient Boosting (XGBoost)
# ----> 2 from xgboost import XGBRegressor
#       3 RegModel=XGBRegressor(max_depth=6, learning_rate=1, n_estimators=100, objective='reg:linear', booster='gbtree')
#       4
#       5 # Printing all the parameters of XGBoost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# Support Vector Machines(SVM)
from sklearn import svm

RegModel = svm.SVR(C=10000, gamma=1,)

# Printing all the parameters of KNN
print(RegModel)

# Creating the model on Training Data
SVM=RegModel.fit(X_train,y_train)
prediction=SVM.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, SVM.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# The built in attribute SVM.coef_ works only for linear kernel
# %matplotlib inline
#feature_importances = pd.Series(SVM.coef_[0], index=Predictors)
#feature_importances.nlargest(10).plot(kind='barh')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# SVR(C=10000, gamma=1)
# R2 Value: 0.6334653339056777
# Accuracy 78.63627100570334
#    Source  Destination  Total_Stops  Duration in minute    Price  \
# 0       1            1            1                 865  10262.0
# 1       0            2            0                 165  19508.0
# 2       1            1            1                1485  10262.0
# 3       1            1            1                 560   6674.0
# 4       1            1            2                1375  15129.0
#
#    PredictedPrice
# 0         10262.0
# 1          4990.0
# 2         12898.0
# 3          7005.0
# 4         13029.0

# %%
# K-Nearest Neighbor(KNN)
from sklearn.neighbors import KNeighborsRegressor
KNNModel = KNeighborsRegressor(n_neighbors=20,weights='distance',algorithm ='auto',p=2,n_jobs=-1,leaf_size=50)

# Printing all the parameters of KNN
print(KNNModel)

# Creating the model on Training Data
KNN=KNNModel.fit(X_train,y_train)
prediction=KNN.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, KNN.predict(X_train)))

# Measuring accuracy on Testing Data
print('Accuracy',100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))

# Plotting the feature importance for Top 10 most important columns
# There is no built-in method to get feature importance in KNN

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)
TestingDataResults.head()
# Out:
# KNeighborsRegressor(leaf_size=50, n_jobs=-1, n_neighbors=20, weights='distance')
# R2 Value: 0.6764424775751336
# Accuracy 77.12962926185565
#    Source  Destination  Total_Stops  Duration in minute    Price  \
# 0       1            1            1                 865  10262.0
# 1       0            2            0                 165  19508.0
# 2       1            1            1                1485  10262.0
# 3       1            1            1                 560   6674.0
# 4       1            1            2                1375  15129.0
#
#    PredictedPrice
# 0          9773.0
# 1          5047.0
# 2         12148.0
# 3          7841.0
# 4         12709.0

# %%
import pickle
file = open('KNN_flight_model.pkl', 'wb')
pickle.dump(KNN, file )
KNNModel
TestingDataResults.shape
# Out:
# (3139, 6)

# %%
a=flight_rate.copy()
a.shape
a
# Out:
#       Source  Destination  Total_Stops    Price  Duration in minute
# 4368       0            2            0   5613.0                 155
# 6384       0            2            0   4823.0                 185
# 426        0            2            0  11793.0                 155
# 3326       2            0            1   7662.0                1515
# 280        2            0            1   8529.0                1495
# ...      ...          ...          ...      ...                 ...
# 706        2            0            1   5608.0                 435
# 7678       2            0            0   4435.0                 155
# 7042       2            0            0   3841.0                 150
# 821        1            1            2  13029.0                1025
# 6854       0            2            1   5746.0                 245
#
# [10462 rows x 5 columns]

# %%
price=a.pop("Price")

# %%
a["Price"]=price
a
a.to_csv("Final DF")

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
all_accuracies = cross_val_score(estimator=KNNModel, X=X_train, y=y_train, cv=5)
all_accuracies

# %%
hyperparameter={"n_neighbors":[6,8,10,12,14,16,18,20],"weights":['uniform', 'distance'],"algorithm":['auto', 'ball_tree', 'kd_tree', 'brute'],"leaf_size" :[30,50,80,100], "p":[2],"n_jobs":[-1]}

# %%
grid = GridSearchCV(estimator=KNN,
                     param_grid=hyperparameter,
                     cv=5,
                     n_jobs=-1,error_score="raise")

# %%
grid.fit(X_train,y_train)

# %%
grid.best_params_

# %%
grid.best_score_

# %%
a=flight_rate.drop("Price",axis=1,inplace=True)

# %%
flight_rate["Price"]=a

# %%
flight_rate
